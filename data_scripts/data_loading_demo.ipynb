# %% [markdown]
# # Data Loading Demo

# %%
import sys
sys.path.append("..")
from data_scripts.data_loading import load_data, partials_n_frames  # New import from our streamlined loader

import os
print(os.getcwd())
# Out:
# /Users/keegz/Documents/Code/Public Builds/SpeakEmbed-T/data_scripts

# %% [markdown]
# ### Loading the Data
#
# During training kindly follow the below mentioned method to avoid unnecessary overlaps and path errors.

# %%
dataset, loader = load_data(
    processed_root="/Users/keegz/Documents/Code/Public Builds/SpeakEmbed-T/data/processed_data",  # !Always requires absolute path
    speakers_per_batch=40,      
    utterances_per_speaker=10,   
    num_workers=0
)

# %%
# Get the first batch from the dataloader
batch = next(iter(loader))

# Explain what a batch is
print("=== Batch Summary ===")
print(f"Batch type: {type(batch)}")
print(f"Number of speakers in batch: {len(batch.speakers)}")
print(f"Combined data shape (utterances x frames x features): {batch.data.shape}")
print()


print("=== Speaker Details ===")
for speaker in batch.speakers:
    # For each speaker, sample one partial utterance
    partials = speaker.random_partial(1, partials_n_frames)
    # Each element is a tuple: (Utterance, partial_frames, (start, end))
    utterance_obj, frames, (start, end) = partials[0]
    
    # Get info: total frames in the original utterance 
    original_frames = utterance_obj.get_frames().shape[0]
    
    print(f"Speaker '{speaker.name}':")
    print(f"  - Sampled partial utterance from frame {start} to {end} (total frames in partial: {frames.shape[0]})")
    print(f"  - Original utterance had {original_frames} frames")
    print(f"  - Partial shape: {frames.shape}")
    print("-" * 40)
# Out:
# === Batch Summary ===
# Batch type: <class 'data_scripts.data_loader.SpeakerBatch'>
# Number of speakers in batch: 40
# Combined data shape (utterances x frames x features): (400, 160, 40)
#
# === Speaker Details ===
# Speaker '198':
#   - Sampled partial utterance from frame 830 to 990 (total frames in partial: 160)
#   - Original utterance had 1366 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '6848':
#   - Sampled partial utterance from frame 109 to 269 (total frames in partial: 160)
#   - Original utterance had 832 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '5514':
#   - Sampled partial utterance from frame 279 to 439 (total frames in partial: 160)
#   - Original utterance had 1507 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '730':
#   - Sampled partial utterance from frame 192 to 352 (total frames in partial: 160)
#   - Original utterance had 667 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1263':
#   - Sampled partial utterance from frame 103 to 263 (total frames in partial: 160)
#   - Original utterance had 994 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '3947':
#   - Sampled partial utterance from frame 498 to 658 (total frames in partial: 160)
#   - Original utterance had 1138 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '696':
#   - Sampled partial utterance from frame 364 to 524 (total frames in partial: 160)
#   - Original utterance had 1306 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '441':
#   - Sampled partial utterance from frame 483 to 643 (total frames in partial: 160)
#   - Original utterance had 1189 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1898':
#   - Sampled partial utterance from frame 142 to 302 (total frames in partial: 160)
#   - Original utterance had 880 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '7059':
#   - Sampled partial utterance from frame 302 to 462 (total frames in partial: 160)
#   - Original utterance had 1255 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '8747':
#   - Sampled partial utterance from frame 124 to 284 (total frames in partial: 160)
#   - Original utterance had 1369 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '8797':
#   - Sampled partial utterance from frame 27 to 187 (total frames in partial: 160)
#   - Original utterance had 832 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '3240':
#   - Sampled partial utterance from frame 36 to 196 (total frames in partial: 160)
#   - Original utterance had 673 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '6531':
#   - Sampled partial utterance from frame 789 to 949 (total frames in partial: 160)
#   - Original utterance had 1018 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '2416':
#   - Sampled partial utterance from frame 1106 to 1266 (total frames in partial: 160)
#   - Original utterance had 1474 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '4195':
#   - Sampled partial utterance from frame 200 to 360 (total frames in partial: 160)
#   - Original utterance had 916 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '2910':
#   - Sampled partial utterance from frame 244 to 404 (total frames in partial: 160)
#   - Original utterance had 1360 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '7264':
#   - Sampled partial utterance from frame 879 to 1039 (total frames in partial: 160)
#   - Original utterance had 1474 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '4137':
#   - Sampled partial utterance from frame 44 to 204 (total frames in partial: 160)
#   - Original utterance had 1117 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '8629':
#   - Sampled partial utterance from frame 338 to 498 (total frames in partial: 160)
#   - Original utterance had 1360 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '250':
#   - Sampled partial utterance from frame 472 to 632 (total frames in partial: 160)
#   - Original utterance had 1006 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '4214':
#   - Sampled partial utterance from frame 182 to 342 (total frames in partial: 160)
#   - Original utterance had 1012 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '3607':
#   - Sampled partial utterance from frame 119 to 279 (total frames in partial: 160)
#   - Original utterance had 421 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '6385':
#   - Sampled partial utterance from frame 403 to 563 (total frames in partial: 160)
#   - Original utterance had 1042 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '4813':
#   - Sampled partial utterance from frame 801 to 961 (total frames in partial: 160)
#   - Original utterance had 1303 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '6081':
#   - Sampled partial utterance from frame 924 to 1084 (total frames in partial: 160)
#   - Original utterance had 1405 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1963':
#   - Sampled partial utterance from frame 695 to 855 (total frames in partial: 160)
#   - Original utterance had 1309 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1553':
#   - Sampled partial utterance from frame 755 to 915 (total frames in partial: 160)
#   - Original utterance had 1408 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1355':
#   - Sampled partial utterance from frame 269 to 429 (total frames in partial: 160)
#   - Original utterance had 1135 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '4441':
#   - Sampled partial utterance from frame 901 to 1061 (total frames in partial: 160)
#   - Original utterance had 1279 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '40':
#   - Sampled partial utterance from frame 318 to 478 (total frames in partial: 160)
#   - Original utterance had 1186 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '2764':
#   - Sampled partial utterance from frame 28 to 188 (total frames in partial: 160)
#   - Original utterance had 403 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '6064':
#   - Sampled partial utterance from frame 709 to 869 (total frames in partial: 160)
#   - Original utterance had 1231 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '3259':
#   - Sampled partial utterance from frame 84 to 244 (total frames in partial: 160)
#   - Original utterance had 859 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '2836':
#   - Sampled partial utterance from frame 360 to 520 (total frames in partial: 160)
#   - Original utterance had 1261 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '8123':
#   - Sampled partial utterance from frame 865 to 1025 (total frames in partial: 160)
#   - Original utterance had 1168 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '831':
#   - Sampled partial utterance from frame 251 to 411 (total frames in partial: 160)
#   - Original utterance had 1165 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '60':
#   - Sampled partial utterance from frame 154 to 314 (total frames in partial: 160)
#   - Original utterance had 916 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '1040':
#   - Sampled partial utterance from frame 56 to 216 (total frames in partial: 160)
#   - Original utterance had 487 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
# Speaker '460':
#   - Sampled partial utterance from frame 219 to 379 (total frames in partial: 160)
#   - Original utterance had 514 frames
#   - Partial shape: (160, 40)
# ----------------------------------------
